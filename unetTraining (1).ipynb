# %%
import os

from google.colab import drive
drive.mount('/content/drive')
path = "/content/drive/MyDrive/esameM"
os.chdir(path)
HOME = os.getcwd()
print(HOME)
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/esameM

# %%
import os

input_dir = f'{HOME}/dataset/origForTrainingUnet/image/'
target_dir = f'{HOME}/dataset/origForTrainingUnet/mask/'
img_size = (256, 256)
num_classes = 2
batch_size = 32

input_img_paths = sorted(
    [
        os.path.join(input_dir, fname)
        for fname in os.listdir(input_dir)
        if fname.endswith(".jpg")
    ]
)
target_img_paths = sorted(
    [
        os.path.join(target_dir, fname)
        for fname in os.listdir(target_dir)
        if fname.endswith(".png") and not fname.startswith(".")
    ]
)

print("Number of samples:", len(input_img_paths))

for input_path, target_path in zip(input_img_paths[:10], target_img_paths[:10]):
    print(input_path, "|", target_path)
# Out:
# Number of samples: 684
# /content/drive/MyDrive/esameM/dataset/origForTrainingUnet/image/healthy100.jpg | /content/drive/MyDrive/esameM/dataset/origForTrainingUnet/mask/healthy100.png
# /content/drive/MyDrive/esameM/dataset/origForTrainingUnet/image/healthy101.jpg | /content/drive/MyDrive/esameM/dataset/origForTrainingUnet/mask/healthy101.png
# /content/drive/MyDrive/esameM/dataset/origForTrainingUnet/image/healthy102.jpg | /content/drive/MyDrive/esameM/dataset/origForTrainingUnet/mask/healthy102.png
# /content/drive/MyDrive/esameM/dataset/origForTrainingUnet/image/healthy103.jpg | /content/drive/MyDrive/esameM/dataset/origForTrainingUnet/mask/healthy103.png
# /content/drive/MyDrive/esameM/dataset/origForTrainingUnet/image/healthy104.jpg | /content/drive/MyDrive/esameM/dataset/origForTrainingUnet/mask/healthy104.png
# /content/drive/MyDrive/esameM/dataset/origForTrainingUnet/image/healthy105.jpg | /content/drive/MyDrive/esameM/dataset/origForTrainingUnet/mask/healthy105.png
# /content/drive/MyDrive/esameM/dataset/origForTrainingUnet/image/healthy106.jpg | /content/drive/MyDrive/esameM/dataset/origForTrainingUnet/mask/healthy106.png
# /content/drive/MyDrive/esameM/dataset/origForTrainingUnet/image/healthy107.jpg | /content/drive/MyDrive/esameM/dataset/origForTrainingUnet/mask/healthy107.png
# /content/drive/MyDrive/esameM/dataset/origForTrainingUnet/image/healthy108.jpg | /content/drive/MyDrive/esameM/dataset/origForTrainingUnet/mask/healthy108.png
# /content/drive/MyDrive/esameM/dataset/origForTrainingUnet/image/healthy109.jpg | /content/drive/MyDrive/esameM/dataset/origForTrainingUnet/mask/healthy109.png

# %%
from IPython.display import Image, display
from keras.utils import load_img
from PIL import ImageOps

# Display input image #7
display(Image(filename=input_img_paths[0]))

# Display auto-contrast version of corresponding target (per-pixel categories)
img = ImageOps.autocontrast(load_img(target_img_paths[0]))
display(img)
# Out:
# <PIL.Image.Image image mode=RGB size=640x480>

# %%
import keras
import numpy as np
from tensorflow import data as tf_data
from tensorflow import image as tf_image
from tensorflow import io as tf_io
import tensorflow as tf
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder

def get_dataset(
    batch_size,
    img_size,
    input_img_paths,
    target_img_paths,
    max_dataset_len=None,
):
    """Returns a TF Dataset."""

    def load_img_masks(input_img_path, target_img_path):
        global num_classes
        input_img = tf_io.read_file(input_img_path)
        input_img = tf_io.decode_jpeg(input_img, channels=3)
        input_img = tf_image.resize(input_img, img_size)
        input_img = tf_image.convert_image_dtype(input_img, "float32")



        target_img = tf_io.read_file(target_img_path)
        target_img = tf_io.decode_png(target_img, channels=1)
        target_img = tf_image.resize(target_img, img_size, method="nearest")
        target_img = tf_image.convert_image_dtype(target_img, "uint8")




        # Ground truth labels are 1, 2, 3. Subtract one to make them 0, 1, 2:
        #target_img -= 1
        #commentato perchè già 0,1

        return input_img, target_img

    # For faster debugging, limit the size of data
    if max_dataset_len:
        input_img_paths = input_img_paths[:max_dataset_len]
        target_img_paths = target_img_paths[:max_dataset_len]
    dataset = tf_data.Dataset.from_tensor_slices((input_img_paths, target_img_paths))
    dataset = dataset.map(load_img_masks, num_parallel_calls=tf_data.AUTOTUNE)
    return dataset.batch(batch_size)

# %%
from keras import layers


def get_model(img_size, num_classes):
    inputs = keras.Input(shape=img_size + (3,))

    ### [First half of the network: downsampling inputs] ###

    # Entry block
    x = layers.Conv2D(32, 3, strides=2, padding="same")(inputs)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)

    previous_block_activation = x  # Set aside residual

    # Blocks 1, 2, 3 are identical apart from the feature depth.
    for filters in [64, 128, 256]:
        x = layers.Activation("relu")(x)
        x = layers.SeparableConv2D(filters, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)

        x = layers.Activation("relu")(x)
        x = layers.SeparableConv2D(filters, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)

        x = layers.MaxPooling2D(3, strides=2, padding="same")(x)

        # Project residual
        residual = layers.Conv2D(filters, 1, strides=2, padding="same")(
            previous_block_activation
        )
        x = layers.add([x, residual])  # Add back residual
        previous_block_activation = x  # Set aside next residual

    ### [Second half of the network: upsampling inputs] ###

    for filters in [256, 128, 64, 32]:
        x = layers.Activation("relu")(x)
        x = layers.Conv2DTranspose(filters, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)

        x = layers.Activation("relu")(x)
        x = layers.Conv2DTranspose(filters, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)

        x = layers.UpSampling2D(2)(x)

        # Project residual
        residual = layers.UpSampling2D(2)(previous_block_activation)
        residual = layers.Conv2D(filters, 1, padding="same")(residual)
        x = layers.add([x, residual])  # Add back residual
        previous_block_activation = x  # Set aside next residual

    # Add a per-pixel classification layer
    outputs = layers.Conv2D(num_classes, 3, activation="softmax", padding="same")(x)

    # Define the model
    model = keras.Model(inputs, outputs)
    return model


# Build model
model = get_model(img_size, num_classes)
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 128, 128,  │        896 │ input_layer[0][0] │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 128, 128,  │        128 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, 128, 128,  │          0 │ activation[0][0]  │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d    │ (None, 128, 128,  │      2,400 │ activation_1[0][… │
# │ (SeparableConv2D)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        256 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_2        │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_1  │ (None, 128, 128,  │      4,736 │ activation_2[0][… │
# │ (SeparableConv2D)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        256 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 64, 64,    │      2,112 │ activation[0][0]  │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 64, 64,    │          0 │ max_pooling2d[0]… │
# │                     │ 64)               │            │ conv2d_1[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_3        │ (None, 64, 64,    │          0 │ add[0][0]         │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_2  │ (None, 64, 64,    │      8,896 │ activation_3[0][… │
# │ (SeparableConv2D)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        512 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_4        │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_3  │ (None, 64, 64,    │     17,664 │ activation_4[0][… │
# │ (SeparableConv2D)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        512 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 32, 32,    │      8,320 │ add[0][0]         │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 32, 32,    │          0 │ max_pooling2d_1[… │
# │                     │ 128)              │            │ conv2d_2[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_5        │ (None, 32, 32,    │          0 │ add_1[0][0]       │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_4  │ (None, 32, 32,    │     34,176 │ activation_5[0][… │
# │ (SeparableConv2D)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      1,024 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_6        │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_5  │ (None, 32, 32,    │     68,096 │ activation_6[0][… │
# │ (SeparableConv2D)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      1,024 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 16, 16,    │     33,024 │ add_1[0][0]       │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 16, 16,    │          0 │ max_pooling2d_2[… │
# │                     │ 256)              │            │ conv2d_3[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_7        │ (None, 16, 16,    │          0 │ add_2[0][0]       │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose    │ (None, 16, 16,    │    590,080 │ activation_7[0][… │
# │ (Conv2DTranspose)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ conv2d_transpose… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_8        │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_1  │ (None, 16, 16,    │    590,080 │ activation_8[0][… │
# │ (Conv2DTranspose)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ conv2d_transpose… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_1     │ (None, 32, 32,    │          0 │ add_2[0][0]       │
# │ (UpSampling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (UpSampling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 32, 32,    │     65,792 │ up_sampling2d_1[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 32, 32,    │          0 │ up_sampling2d[0]… │
# │                     │ 256)              │            │ conv2d_4[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_9        │ (None, 32, 32,    │          0 │ add_3[0][0]       │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_2  │ (None, 32, 32,    │    295,040 │ activation_9[0][… │
# │ (Conv2DTranspose)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_transpose… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_10       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_3  │ (None, 32, 32,    │    147,584 │ activation_10[0]… │
# │ (Conv2DTranspose)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_transpose… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_3     │ (None, 64, 64,    │          0 │ add_3[0][0]       │
# │ (UpSampling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_2     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (UpSampling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 64, 64,    │     32,896 │ up_sampling2d_3[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_4 (Add)         │ (None, 64, 64,    │          0 │ up_sampling2d_2[… │
# │                     │ 128)              │            │ conv2d_5[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_11       │ (None, 64, 64,    │          0 │ add_4[0][0]       │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_4  │ (None, 64, 64,    │     73,792 │ activation_11[0]… │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_transpose… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_12       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_5  │ (None, 64, 64,    │     36,928 │ activation_12[0]… │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_transpose… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_5     │ (None, 128, 128,  │          0 │ add_4[0][0]       │
# │ (UpSampling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_4     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (UpSampling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 128, 128,  │      8,256 │ up_sampling2d_5[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_5 (Add)         │ (None, 128, 128,  │          0 │ up_sampling2d_4[… │
# │                     │ 64)               │            │ conv2d_6[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_13       │ (None, 128, 128,  │          0 │ add_5[0][0]       │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_6  │ (None, 128, 128,  │     18,464 │ activation_13[0]… │
# │ (Conv2DTranspose)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_transpose… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_14       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_7  │ (None, 128, 128,  │      9,248 │ activation_14[0]… │
# │ (Conv2DTranspose)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_transpose… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_7     │ (None, 256, 256,  │          0 │ add_5[0][0]       │
# │ (UpSampling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_6     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (UpSampling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 256, 256,  │      2,080 │ up_sampling2d_7[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_6 (Add)         │ (None, 256, 256,  │          0 │ up_sampling2d_6[… │
# │                     │ 32)               │            │ conv2d_7[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 256, 256,  │        578 │ add_6[0][0]       │
# │                     │ 2)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 2,058,690 (7.85 MB)
#  Trainable params: 2,054,914 (7.84 MB)
#  Non-trainable params: 3,776 (14.75 KB)

# %%
import random

# Split our img paths into a training and a validation set
val_samples = 76
random.Random(1337).shuffle(input_img_paths)
random.Random(1337).shuffle(target_img_paths)
train_input_img_paths = input_img_paths[:-val_samples]
train_target_img_paths = target_img_paths[:-val_samples]
val_input_img_paths = input_img_paths[-val_samples:]
val_target_img_paths = target_img_paths[-val_samples:]

# Instantiate dataset for each split
train_dataset = get_dataset(
    batch_size,
    img_size,
    train_input_img_paths,
    train_target_img_paths,
)
valid_dataset = get_dataset(
    batch_size, img_size, val_input_img_paths, val_target_img_paths
)

# %%
# Configure the model for training.
# We use the "sparse" version of categorical_crossentropy
# because our target data is integers.
model.compile(
    optimizer=keras.optimizers.Adam(1e-4), loss="sparse_categorical_crossentropy"
)

callbacks = [
    keras.callbacks.ModelCheckpoint( f'{HOME}/model/betta_unet_segmentation.keras', save_best_only=True)
]

# Train the model, doing validation at the end of each epoch.
epochs = 100
model.fit(
    train_dataset,
    epochs=epochs,
    validation_data=valid_dataset,
    callbacks=callbacks,
    verbose=2,
)
# Out:
# Epoch 1/100
# 19/19 - 236s - 12s/step - loss: 0.7586 - val_loss: 1.4520
# Epoch 2/100
# 19/19 - 7s - 364ms/step - loss: 0.3167 - val_loss: 0.8337
# Epoch 3/100
# 19/19 - 7s - 372ms/step - loss: 0.2462 - val_loss: 0.5798
# Epoch 4/100
# 19/19 - 7s - 363ms/step - loss: 0.2048 - val_loss: 0.5288
# Epoch 5/100
# 19/19 - 7s - 362ms/step - loss: 0.1793 - val_loss: 0.4992
# Epoch 6/100
# 19/19 - 7s - 356ms/step - loss: 0.1617 - val_loss: 0.4775
# Epoch 7/100
# 19/19 - 8s - 407ms/step - loss: 0.1478 - val_loss: 0.4680
# Epoch 8/100
# 19/19 - 7s - 347ms/step - loss: 0.1364 - val_loss: 0.4650
# Epoch 9/100
# 19/19 - 6s - 333ms/step - loss: 0.1265 - val_loss: 0.4652
# Epoch 10/100
# 19/19 - 8s - 411ms/step - loss: 0.1177 - val_loss: 0.4657
# Epoch 11/100
# 19/19 - 6s - 324ms/step - loss: 0.1102 - val_loss: 0.4710
# Epoch 12/100
# 19/19 - 7s - 354ms/step - loss: 0.1040 - val_loss: 0.4767
# Epoch 13/100
# 19/19 - 10s - 549ms/step - loss: 0.1008 - val_loss: 0.4745
# Epoch 14/100
# 19/19 - 6s - 322ms/step - loss: 0.1102 - val_loss: 0.5587
# Epoch 15/100
# 19/19 - 7s - 357ms/step - loss: 0.1086 - val_loss: 0.4215
# Epoch 16/100
# 19/19 - 6s - 342ms/step - loss: 0.0946 - val_loss: 0.4518
# Epoch 17/100
# 19/19 - 11s - 573ms/step - loss: 0.0895 - val_loss: 0.4528
# Epoch 18/100
# 19/19 - 6s - 314ms/step - loss: 0.0833 - val_loss: 0.4921
# Epoch 19/100
# 19/19 - 7s - 375ms/step - loss: 0.0793 - val_loss: 0.5226
# Epoch 20/100
# 19/19 - 6s - 319ms/step - loss: 0.0774 - val_loss: 0.4734
# Epoch 21/100
# 19/19 - 7s - 361ms/step - loss: 0.0742 - val_loss: 0.4691
# Epoch 22/100
# 19/19 - 6s - 324ms/step - loss: 0.0709 - val_loss: 0.4331
# Epoch 23/100
# 19/19 - 7s - 355ms/step - loss: 0.0679 - val_loss: 0.3955
# Epoch 24/100
# 19/19 - 7s - 364ms/step - loss: 0.0672 - val_loss: 0.3765
# Epoch 25/100
# 19/19 - 7s - 381ms/step - loss: 0.0671 - val_loss: 0.3710
# Epoch 26/100
# 19/19 - 7s - 369ms/step - loss: 0.0662 - val_loss: 0.3798
# Epoch 27/100
# 19/19 - 7s - 354ms/step - loss: 0.0620 - val_loss: 0.3632
# Epoch 28/100
# 19/19 - 7s - 364ms/step - loss: 0.0621 - val_loss: 0.2953
# Epoch 29/100
# 19/19 - 7s - 353ms/step - loss: 0.0599 - val_loss: 0.2920
# Epoch 30/100
# 19/19 - 8s - 406ms/step - loss: 0.0577 - val_loss: 0.2458
# Epoch 31/100
# 19/19 - 7s - 378ms/step - loss: 0.0530 - val_loss: 0.2340
# Epoch 32/100
# 19/19 - 7s - 361ms/step - loss: 0.0504 - val_loss: 0.2184
# Epoch 33/100
# 19/19 - 8s - 405ms/step - loss: 0.0485 - val_loss: 0.2005
# Epoch 34/100
# 19/19 - 7s - 359ms/step - loss: 0.0478 - val_loss: 0.1942
# Epoch 35/100
# 19/19 - 7s - 382ms/step - loss: 0.0478 - val_loss: 0.1888
# Epoch 36/100
# 19/19 - 7s - 384ms/step - loss: 0.0482 - val_loss: 0.1739
# Epoch 37/100
# 19/19 - 7s - 381ms/step - loss: 0.0498 - val_loss: 0.1555
# Epoch 38/100
# 19/19 - 10s - 543ms/step - loss: 0.0558 - val_loss: 0.1517
# Epoch 39/100
# 19/19 - 7s - 368ms/step - loss: 0.0528 - val_loss: 0.1566
# Epoch 40/100
# 19/19 - 7s - 345ms/step - loss: 0.0514 - val_loss: 0.1745
# Epoch 41/100
# 19/19 - 7s - 365ms/step - loss: 0.0595 - val_loss: 0.1692
# Epoch 42/100
# 19/19 - 6s - 321ms/step - loss: 0.0669 - val_loss: 0.1561
# Epoch 43/100
# 19/19 - 7s - 369ms/step - loss: 0.0670 - val_loss: 0.1351
# Epoch 44/100
# 19/19 - 7s - 374ms/step - loss: 0.0574 - val_loss: 0.1303
# Epoch 45/100
# 19/19 - 7s - 365ms/step - loss: 0.0492 - val_loss: 0.1278
# Epoch 46/100
# 19/19 - 10s - 552ms/step - loss: 0.0445 - val_loss: 0.1324
# Epoch 47/100
# 19/19 - 7s - 355ms/step - loss: 0.0453 - val_loss: 0.1282
# Epoch 48/100
# 19/19 - 6s - 337ms/step - loss: 0.0469 - val_loss: 0.1215
# Epoch 49/100
# 19/19 - 7s - 369ms/step - loss: 0.0449 - val_loss: 0.1401
# Epoch 50/100
# 19/19 - 7s - 347ms/step - loss: 0.0439 - val_loss: 0.1410
# Epoch 51/100
# 19/19 - 7s - 352ms/step - loss: 0.0417 - val_loss: 0.1278
# Epoch 52/100
# 19/19 - 6s - 317ms/step - loss: 0.0372 - val_loss: 0.1299
# Epoch 53/100
# 19/19 - 7s - 380ms/step - loss: 0.0363 - val_loss: 0.1321
# Epoch 54/100
# 19/19 - 6s - 317ms/step - loss: 0.0346 - val_loss: 0.1372
# Epoch 55/100
# 19/19 - 6s - 333ms/step - loss: 0.0341 - val_loss: 0.1379
# Epoch 56/100
# 19/19 - 10s - 520ms/step - loss: 0.0339 - val_loss: 0.1447
# Epoch 57/100
# 19/19 - 7s - 369ms/step - loss: 0.0337 - val_loss: 0.1485
# Epoch 58/100
# 19/19 - 9s - 497ms/step - loss: 0.0336 - val_loss: 0.1439
# Epoch 59/100
# 19/19 - 7s - 365ms/step - loss: 0.0335 - val_loss: 0.1452
# Epoch 60/100
# 19/19 - 6s - 323ms/step - loss: 0.0341 - val_loss: 0.1460
# Epoch 61/100
# 19/19 - 7s - 368ms/step - loss: 0.0343 - val_loss: 0.1416
# Epoch 62/100
# 19/19 - 6s - 322ms/step - loss: 0.0345 - val_loss: 0.1414
# Epoch 63/100
# 19/19 - 7s - 355ms/step - loss: 0.0365 - val_loss: 0.1402
# Epoch 64/100
# 19/19 - 9s - 497ms/step - loss: 0.0371 - val_loss: 0.1446
# Epoch 65/100
# 19/19 - 7s - 363ms/step - loss: 0.0378 - val_loss: 0.1461
# Epoch 66/100
# 19/19 - 6s - 314ms/step - loss: 0.0360 - val_loss: 0.1502
# Epoch 67/100
# 19/19 - 7s - 356ms/step - loss: 0.0367 - val_loss: 0.1610
# Epoch 68/100
# 19/19 - 6s - 319ms/step - loss: 0.0338 - val_loss: 0.1871
# Epoch 69/100
# 19/19 - 7s - 351ms/step - loss: 0.0321 - val_loss: 0.2161
# Epoch 70/100
# 19/19 - 10s - 504ms/step - loss: 0.0314 - val_loss: 0.2498
# Epoch 71/100
# 19/19 - 7s - 378ms/step - loss: 0.0310 - val_loss: 0.3104
# Epoch 72/100
# 19/19 - 10s - 512ms/step - loss: 0.0320 - val_loss: 0.2781
# Epoch 73/100
# 19/19 - 7s - 354ms/step - loss: 0.0320 - val_loss: 0.1449
# Epoch 74/100
# 19/19 - 11s - 568ms/step - loss: 0.0317 - val_loss: 0.1469
# Epoch 75/100
# 19/19 - 6s - 317ms/step - loss: 0.0304 - val_loss: 0.1498
# Epoch 76/100
# 19/19 - 6s - 333ms/step - loss: 0.0303 - val_loss: 0.1491
# Epoch 77/100
# 19/19 - 6s - 339ms/step - loss: 0.0306 - val_loss: 0.1421
# Epoch 78/100
# 19/19 - 6s - 329ms/step - loss: 0.0303 - val_loss: 0.1491
# Epoch 79/100
# 19/19 - 7s - 352ms/step - loss: 0.0308 - val_loss: 0.1532
# Epoch 80/100
# 19/19 - 6s - 318ms/step - loss: 0.0309 - val_loss: 0.1589
# Epoch 81/100
# 19/19 - 7s - 366ms/step - loss: 0.0317 - val_loss: 0.1615
# Epoch 82/100
# 19/19 - 6s - 318ms/step - loss: 0.0325 - val_loss: 0.1558
# Epoch 83/100
# 19/19 - 7s - 364ms/step - loss: 0.0336 - val_loss: 0.1479
# Epoch 84/100
# 19/19 - 6s - 339ms/step - loss: 0.0350 - val_loss: 0.1536
# Epoch 85/100
# 19/19 - 8s - 409ms/step - loss: 0.0350 - val_loss: 0.1799
# Epoch 86/100
# 19/19 - 7s - 379ms/step - loss: 0.0331 - val_loss: 0.1706
# Epoch 87/100
# 19/19 - 7s - 381ms/step - loss: 0.0326 - val_loss: 0.1535
# Epoch 88/100
# 19/19 - 6s - 333ms/step - loss: 0.0318 - val_loss: 0.1466
# Epoch 89/100
# 19/19 - 6s - 342ms/step - loss: 0.0322 - val_loss: 0.1591
# Epoch 90/100
# 19/19 - 7s - 352ms/step - loss: 0.0331 - val_loss: 0.1692
# Epoch 91/100
# 19/19 - 6s - 324ms/step - loss: 0.0320 - val_loss: 0.1838
# Epoch 92/100
# 19/19 - 7s - 377ms/step - loss: 0.0318 - val_loss: 0.1701
# Epoch 93/100
# 19/19 - 6s - 318ms/step - loss: 0.0296 - val_loss: 0.1506
# Epoch 94/100
# 19/19 - 7s - 371ms/step - loss: 0.0287 - val_loss: 0.1463
# Epoch 95/100
# 19/19 - 10s - 520ms/step - loss: 0.0276 - val_loss: 0.1485
# Epoch 96/100
# 19/19 - 7s - 356ms/step - loss: 0.0276 - val_loss: 0.1575
# Epoch 97/100
# 19/19 - 6s - 317ms/step - loss: 0.0278 - val_loss: 0.1799
# Epoch 98/100
# 19/19 - 7s - 385ms/step - loss: 0.0277 - val_loss: 0.1630
# Epoch 99/100
# 19/19 - 10s - 508ms/step - loss: 0.0269 - val_loss: 0.1591
# Epoch 100/100
# 19/19 - 7s - 343ms/step - loss: 0.0255 - val_loss: 0.1752

# %%
# Generate predictions for all images in the validation set

val_dataset = get_dataset(
    batch_size, img_size, val_input_img_paths, val_target_img_paths
)
val_preds = model.predict(val_dataset)


def display_mask(i):
    """Quick utility to display a model's prediction."""
    mask = np.argmax(val_preds[i], axis=-1)
    mask = np.expand_dims(mask, axis=-1)
    img = ImageOps.autocontrast(keras.utils.array_to_img(mask))
    display(img)


# Display results for validation image #10
i = 10

# Display input image
display(Image(filename=val_input_img_paths[i]))

# Display ground-truth target mask
img = ImageOps.autocontrast(load_img(val_target_img_paths[i]))
display(img)

# Display mask predicted by our model
display_mask(i)  # Note that the model only sees inputs at 150x150.
# Out:
# Tensor("Identity:0", shape=(256, 256, 3), dtype=float32)
# luca
# Tensor("Identity_1:0", shape=(256, 256, 1), dtype=uint8)
# luca
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step
# <PIL.Image.Image image mode=RGB size=640x480>
# <PIL.Image.Image image mode=L size=256x256>
